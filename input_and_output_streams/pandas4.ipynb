# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.options.display.max_rows = 7
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 3)
plt.rcParams['font.family'] = 'sans-serif'

# %%
en_climate_daily = pd.read_csv('en_climate_daily.csv', index_col='Date/Time')
en_climate_daily['Total Snow (cm)'].plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='Date/Time'>

# %%
url_template = "http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=5415&Year={year}&Month={month}&timeframe=1&submit=Download+Data"

# %%
url = url_template.format(month=3, year=2012)
weather_march2012 = pd.read_csv(url, skiprows=15, parse_dates=True, encoding='latin1')

# %%
weather_march2012
# Out:
#      -73.75  45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A  7025250  \
# 0    -73.75  45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A  7025250
# 1    -73.75  45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A  7025250
# 2    -73.75  45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A  7025250
# ..      ...    ...                                     ...      ...
# 726  -73.75  45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A  7025250
# 727  -73.75  45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A  7025250
# 728  -73.75  45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A  7025250
#
#      2012-03-01 14:00  2012  03  01  14:00  -3.9  ...  Unnamed: 20   1.2  \
# 0    2012-03-01 15:00  2012   3   1  15:00  -3.3  ...          NaN   1.6
# 1    2012-03-01 16:00  2012   3   1  16:00  -2.7  ...          NaN   2.4
# 2    2012-03-01 17:00  2012   3   1  17:00  -2.9  ...          NaN   4.0
# ..                ...   ...  ..  ..    ...   ...  ...          ...   ...
# 726  2012-03-31 21:00  2012   3  31  21:00   2.6  ...          NaN  25.0
# 727  2012-03-31 22:00  2012   3  31  22:00   2.7  ...          NaN  25.0
# 728  2012-03-31 23:00  2012   3  31  23:00   1.5  ...          NaN  25.0
#
#      Unnamed: 22  100.67  Unnamed: 24  Unnamed: 25  Unnamed: 26   -11  \
# 0            NaN  100.71          NaN          NaN          NaN -10.0
# 1            NaN  100.74          NaN          NaN          NaN  -8.0
# 2            NaN  100.80          NaN          NaN          NaN  -9.0
# ..           ...     ...          ...          ...          ...   ...
# 726          NaN  100.86          NaN          NaN          NaN   NaN
# 727          NaN  100.82          NaN          NaN          NaN   NaN
# 728          NaN  100.79          NaN          NaN          NaN   NaN
#
#      Unnamed: 28   Snow
# 0            NaN   Snow
# 1            NaN   Snow
# 2            NaN   Snow
# ..           ...    ...
# 726          NaN  Clear
# 727          NaN  Clear
# 728          NaN  Clear
#
# [729 rows x 30 columns]
